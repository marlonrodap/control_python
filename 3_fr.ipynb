# %% [markdown]
# # Frequency Response
#
# ![FR](/Users/marlonrodriguez/Library/CloudStorage/OneDrive-KULeuven/Programming/py/control_python/images/fr.png "FR")

# %% [markdown]
#  # Assume we have the following transfer function
#
#  ![TF2](/Users/marlonrodriguez/Library/CloudStorage/OneDrive-KULeuven/Programming/py/control_python/images/tf2.png "TF2")

# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt

# %%
# Define Transfer Function
num1 = np.array([3])
num2 = np.array([2, 1])
num = np.convolve(num1, num2)

den1 = np.array([3, 1])
den2 = np.array([5, 1])
den = np.convolve(den1, den2)

H = sig.TransferFunction(num, den)

# Frequencies
w_start = 0.01
w_stop = 10
step = 0.01
N = int ((w_stop - w_start)/step) + 1
w = np.linspace(w_start, w_stop, N)

# Bode Plot
w, mag, phase = sig.bode(H, w)

plt.subplot(2, 1, 1)
plt.semilogx(w,mag) # Bode Magnitude Plot
plt.title("Bode Plot")
plt.grid(visible = None, which = "major", axis = "both")
plt.grid(visible = None, which = "minor", axis = "both")
plt.ylabel("Magnitude (dB)")

plt.subplot(2, 1, 2)
plt.semilogx(w, phase) # Bode Phase Plot
plt.grid(visible = None, which = "major", axis = "both")
plt.grid(visible = None, which = "minor", axis = "both")
plt.ylabel("Phase (deg)")
plt.xlabel("Frequency (rad/sec)")
# Out:
# Text(0.5, 0, 'Frequency (rad/sec)')

# %% [markdown]
# Now we use the control toolbox to draw the bode plot

# %%
import control

# %%
H = control.tf(num, den)
print("H(s)=", H)
# Out:
# H(s)=
#     6 s + 3
# ----------------
# 15 s^2 + 8 s + 1

# %%
# Bode Plot
control.bode(H, dB = True)
# Out:
# (array([2.99550853, 2.99544611, 2.99538282, 2.99531865, 2.99525359,
#         2.99518763, 2.99512075, 2.99505295, 2.9949842 , 2.99491451,
#         2.99484384, 2.9947722 , 2.99469956, 2.99462592, 2.99455125,
#         2.99447556, 2.99439881, 2.994321  , 2.99424211, 2.99416212,
#         2.99408103, 2.99399881, 2.99391546, 2.99383095, 2.99374527,
#         2.9936584 , 2.99357034, 2.99348105, 2.99339052, 2.99329874,
#         2.99320569, 2.99311135, 2.99301571, 2.99291874, 2.99282043,
#         2.99272076, 2.99261971, 2.99251726, 2.99241339, 2.99230809,
#         2.99220133, 2.99209309, 2.99198335, 2.9918721 , 2.99175931,
#         2.99164496, 2.99152903, 2.9914115 , 2.99129234, 2.99117153,
#         2.99104905, 2.99092489, 2.990799  , 2.99067138, 2.99054199,
#         2.99041082, 2.99027783, 2.99014301, 2.99000633, 2.98986776,
#         2.98972727, 2.98958485, 2.98944046, 2.98929408, 2.98914568,
#         2.98899523, 2.9888427 , 2.98868807, 2.98853131, 2.98837239,
# ...
